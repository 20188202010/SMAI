# %%
#read datafolder from Google Drive
from google.colab import drive
drive.mount('/content/drive')
data_folder = '/content/drive/My Drive/SMAI/Assignments&Projects/Project/reuters21578/'


sgml_number_of_files = 21
sgml_file_name_template = 'reut2-NNN.sgm'

# Category files
category_files = {
    'to_': ('Topics', 'all-topics-strings.lc.txt'),
    'pl_': ('Places', 'all-places-strings.lc.txt'),
    'pe_': ('People', 'all-people-strings.lc.txt'),
    'or_': ('Organizations', 'all-orgs-strings.lc.txt'),
    'ex_': ('Exchanges', 'all-exchanges-strings.lc.txt')
}
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
# Read all categories
category_data = []
category_dictionary={'Topics':[],'Places':[],'People':[],'Organizations':[],'Exchanges':[]}
for category_prefix in category_files.keys():
    with open(data_folder + category_files[category_prefix][1], 'r') as file:
        for category in file.readlines():
            category_data.append([category_prefix + category.strip().lower(), 
                                  category_files[category_prefix][0]])

# Create category dataframe
for i in category_data:
    category_dictionary[i[1]].append(i[0].split('_')[1])
news_categories = pd.DataFrame(data=category_data)

# %%
import re
import xml.sax.saxutils as saxutils
from bs4 import BeautifulSoup
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
lemmatizer = WordNetLemmatizer()

REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;\\n]')
BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
STOPWORDS = set(stopwords.words('english'))

def cleanUpSentence(r):#, stop_words = None#
    r = r.lower().replace("<br />", " ")
    r = REPLACE_BY_SPACE_RE.sub(' ', r)
    r = BAD_SYMBOLS_RE.sub('', r)

    r = ' '.join(word for word in r.split() if word not in STOPWORDS)

    words = word_tokenize(r)

    for w in words:
        w = lemmatizer.lemmatize(w)

    return r

# %%
# Parse SGML files
def strip_tags(text):
    return re.sub('<[^<]+?>', '', text).strip()

def unescape(text):
    return saxutils.unescape(text)
  
def makeDict(filename, document_X):
  with open(filename, 'rb') as file:

    content = BeautifulSoup(file.read().lower(),'html.parser')

    for newsline in content('reuters'):
      document_categories = []

      document_id = newsline['newid']
      document_body = strip_tags(str(newsline('text')[0].body)).replace('reuter\n&#3;', '')
      if document_body == 'None':
        continue

      doc_categories = strip_tags(str(newsline('topics')[0].body))
      doc_categories = unescape(doc_categories)

      document_body = unescape(document_body)

      document_X[document_id] = document_body
      

def readFiles(test_data = False):
  document_X = {}
  
  if test_data == True:
    file_name = sgml_file_name_template.replace('NNN', '021')
    filename = data_folder + file_name
    makeDict(filename, document_X)
  else:
    for i in range(sgml_number_of_files):
      if i < 10:
        seq = '00' + str(i)
      else:
        seq = '0' + str(i)

      file_name = sgml_file_name_template.replace('NNN', seq)
      print('Reading file: %s' % file_name)
      filename = data_folder + file_name
      makeDict(filename, document_X)
  return document_X

# %%
document_X = readFiles()
# Out:
# Reading file: reut2-000.sgm
# Reading file: reut2-001.sgm
# Reading file: reut2-002.sgm
# Reading file: reut2-003.sgm
# Reading file: reut2-004.sgm
# Reading file: reut2-005.sgm
# Reading file: reut2-006.sgm
# Reading file: reut2-007.sgm
# Reading file: reut2-008.sgm
# Reading file: reut2-009.sgm
# Reading file: reut2-010.sgm
# Reading file: reut2-011.sgm
# Reading file: reut2-012.sgm
# Reading file: reut2-013.sgm
# Reading file: reut2-014.sgm
# Reading file: reut2-015.sgm
# Reading file: reut2-016.sgm
# Reading file: reut2-017.sgm
# Reading file: reut2-018.sgm
# Reading file: reut2-019.sgm
# Reading file: reut2-020.sgm

# %%
# data preprocessing
import numpy as np

nltk.download('punkt')
nltk.download('wordnet')
def create_x_matrix(document_X):
    totalX = []
    for i, doc in document_X.items():
        totalX.append(cleanUpSentence(doc))
    max_vocab_size = 200
    input_tokenizer = Tokenizer(max_vocab_size)
    input_tokenizer.fit_on_texts(totalX)
    encoded_docs = input_tokenizer.texts_to_matrix(totalX, mode='count')
    return totalX,encoded_docs
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
totalX,encoded_docs=create_x_matrix(document_X)

# %%
#Create one-hot encode
def makeOneHotEncoding(totalX):
  words_in_body={}

  for i in range(len(totalX)):
      words=totalX[i].split(' ')
      words_in_body[i]=words    

  one_hot_label=[]
  for key,v in words_in_body.items():
      dict_temp={'Topics':0,'Places':0,'People':0,'Exchanges':0,'Organizations':0}
      for i in v:
          if i in category_dictionary['Topics']:
              dict_temp['Topics']+=1
          if i in category_dictionary['Places']:
              dict_temp['Places']+=1
          if i in category_dictionary['People']:
              dict_temp['People']+=1
          if i in category_dictionary['Exchanges']:
              dict_temp['Exchanges']+=1
          if i in category_dictionary['Organizations']:
              dict_temp['Organizations']+=1

      one_hot_label.append(dict_temp)


  one_hot_label_list = []
  for i in one_hot_label:

      one_hot_label_list.append(list(i.values()))
  return one_hot_label_list

# %%
one_hot_label_list = makeOneHotEncoding(totalX)

# %%
# !pip3 install scikit-multilearn
# Out:
# Requirement already satisfied: scikit-multilearn in /usr/local/lib/python3.6/dist-packages (0.2.0)

# %%
from skmultilearn.problem_transform import ClassifierChain
from sklearn.linear_model import LogisticRegression

# ignore all future warnings
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)

X = np.array(encoded_docs)
Y = np.array(one_hot_label_list)
# initialize classifier chains multi-label classifier
classifier = ClassifierChain(LogisticRegression())
# Training logistic regression model on train data
classifier.fit(X, Y)
# Out:
# ClassifierChain(classifier=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False),
#         order=None, require_dense=[True, True])

# %%
def getRankedOutput2(predicted_y):
  all_sorted_x = []
  for i in predicted_y:
    dict_temp={'Topics':i[0],'Places':i[1],'Peoples':i[2],'Exchanges':i[3],'Organizations':i[4]}
    sorted_x = sorted(dict_temp.items(), key=lambda kv: kv[1], reverse=True) 
    all_sorted_x.append(sorted_x)
  return all_sorted_x

# %%
def permissible(x, y):
  if (abs(x-y)) < 2:
    return True
  else:
    return False

def accuracy(predicted,actual):
    tp=0
    fp = 0
    tp_list = []
    length = len(actual)
    print("length: ",length)
    for one_doc_idx in range(length):
        if permissible(predicted[one_doc_idx][0],actual[one_doc_idx][0]) and permissible(predicted[one_doc_idx][1],actual[one_doc_idx][1])\
          and permissible(predicted[one_doc_idx][2],actual[one_doc_idx][2]) and permissible(predicted[one_doc_idx][3],actual[one_doc_idx][3]):
            tp+=1
            x = tp
        else:
          fp = 0
          x = fp
        tp_list.append(x)
    return tp/float(length), tp_list

# %%
val_x_doc = readFiles(test_data = True)
totalX_test, encoded_val_x = create_x_matrix(val_x_doc)
ground_truth_val = makeOneHotEncoding(totalX_test)

# %%
X = np.array(encoded_val_x)
Y = np.array(ground_truth_val)

val_pred = classifier.predict(X)
val_pred_arr = val_pred.toarray()

# %%
validate_y_list = val_pred_arr.tolist()

newv = []
for i in range(len(validate_y_list)):
  validate_y_list_i = list(map(int, validate_y_list[i]))
  newv.append(validate_y_list_i)

acc,tpl=accuracy(newv, ground_truth_val)
print ("%f"%acc)
pred_rank_list = getRankedOutput2(val_pred_arr)
actual_rank_list = getRankedOutput2(Y)
# Out:
# length:  460
# 0.689130

# %%
pd.set_option('max_colwidth', 100)
my_df  = pd.DataFrame(columns = ['body', 'predicted ranking', 'actual ranking', '_'])
my_df['body'] = totalX_test
my_df['predicted ranking'] = pred_rank_list
my_df['actual ranking'] = actual_rank_list
my_df['_'] = tpl
my_df = my_df.sort_values(by='_', ascending=False).reset_index(drop=True)
my_df[['body', 'predicted ranking', 'actual ranking']]
# Out:
#                                                                                                     body  \
# 0    chase corp ltd chcawe said make offer fullypaid shares options entregrowth international ltd alr...
# 1    iranian president ali khamenei said doubted us position take violent action iran gulf tehran rad...
# 2    nippon shinpan co ltd nshtt agreed mastercard international issue new credit card called nippon ...
# 3    continental airlines inc said frontier airlines bought last year sought approval us bankruptcy c...
# 4    lebanons bankers association said extended suspension trading lebanese pound two working days st...
# 5    equiticorp holdings ltd equwwe owns received acceptances representing 5993 pct issued ordinary s...
# 6    british printing communication corporation plc bpcll proposed cancellation preference shares ret...
# 7    west german finance ministry declined comment weekend criticism us treasury secretary james bake...
# 8    norways current account showed 99 billion crown deficit first seven months 1987 197 billion crow...
# 9    williams holdings plc said mandated barclays de zoete wedd ltd arrange 100 mln stg multiple opti...
# 10   fletcher challenge ltd fltcwe fcl announced striking price 589 nz dlrs share shareholders electe...
# 11   toyota motor corp toyot volkswagen ag vowgf considering raising local procurement rate west germ...
# 12   sprint ii special purpose corporation based cayman islands issuing 35 mln dlrs floating rate bon...
# 13   trafalgar house plc trafl said acquired entire share capital capital homes inc us 20 mln dlrs ca...
# 14   south yemen planning major oil pipeline system completed 18months time start exports initial rat...
# 15   puma ag rudolf dassler sport pumaf said posted 1987 firsthalf group loss 14 mln marks largest po...
# 16   shr 36 cts vs 36 cts shr diluted 34 cts vs 31 cts net 1 679 000 vs 1 418 000 sales 1472 mln vs 1...
# 17   shr loss nine cts vs loss 12 cts net loss 649 000 vs loss 850 000 revs 5 059 000 vs 4 084 000 av...
# 18   bechtel corp said formed joint venture control resource industries inc called bechtelcontrol asb...
# 19   quantech electronics corp said common stock continue quoted nasdaq system due exception national...
# 20   unidentified jets raided three iranian oil rigs southern gulf monday setting least one ablaze re...
# 21   privatelyheld neorx corp said entered exclusive agreement genentech inc development injectable d...
# 22   shr 18 cts vs 13 cts net 5 436 000 vs 3 888 000 sales 439 mln vs 315 mln avg shrs 30 145 000 vs ...
# 23   shr 13 cts vs 12 cts net 1 612 000 vs 1 571 000 revs 288 mln vs 250 mln avg shrs 128 mln vs 133 ...
# 24   deutsche bank ag joint chief executive friedrich wilhelm christians said believed louvre accord ...
# 25   shr 30 cts vs 17 cts shr diluted 30 cts vs 17 cts net 3 454 000 vs 1 546 000 sales 840 mln vs 59...
# 26   tandem computers inc said introduced 84gigabyte writeonce readmanytimes optical disk library sub...
# 27   texaco inc said asked committee shareholders possibility company paying preferred stock dividend...
# 28   cable wireless plc cawll said subsidiary hong kong telephone co ltd would cease listed company f...
# 29   shamrock capital lp said completed sale cental soya co inc ferruzzi agricola finanziaria holding...
# ..                                                                                                   ...
# 430  australian minister trade negotiations michael duffy said country third world commodity producer...
# 431  turkeys current account deficit widened july 674 mln dlrs 454 mln june fell 122 billion july las...
# 432  american vision centers inc said michael c barlerin elected president chief operating officer co...
# 433  nui corp said studying feasibility spinning nonutility subsidiaries shareholders company said pr...
# 434  todays sharp selloff swiss stocks matching falls around europe may overdone mood financial marke...
# 435  soviet planning chief nikolai talyzin told supreme soviet parliament industrial output planned r...
# 436  american telephone telegraph co said plans build new computer incorrates unified version unix sy...
# 437  iran said us naval forces attacked two oil platforms southern gulf monday afternoon iranian news...
# 438  federal reserve expected enter government securities market supply reserves banking system via s...
# 439  federal deposit insurance corp chairman william seidman said would concerned impact banks sharp ...
# 440  recent sharp rise us interest rates sparked turmoil fixedincome markets underwriters said doubt ...
# 441  west german government sources said bonn remained committed louvre accord stabilise currencies s...
# 442  corby distilleries ltd said agreed buy torontobased mcguinness distillers ltd heublein inc 45 ml...
# 443  anchor glass container corp said expects fourth quarter profits exceed 47 mln dlrs reported thir...
# 444  canadian auto workers union said accepted economic offer canadian division general motors corp g...
# 445  monsanto co said sales nutrasweet artificial sweetener fell slightly third quarter due continuin...
# 446  japans ruling liberal democratic party ldp tuesdayhose former finance minister noboru takeshita ...
# 447  louvre accord currency stability maintained uneasy calm currency markets since last february app...
# 448  shareholder group led barris industries inc brsso said acquired 98 pct stake media general inc c...
# 449  mining group boliden ab said agreed saudi state agency general petroleum mineral organisation pe...
# 450  wang laboratories inc announced four additions vs line minicomputers said offer double capacity ...
# 451  securities exchange commission chairman david ruder said brief trading halt discussed one way re...
# 452  circle fine art corp said completed exclusive license agreement seiyoken group toyko open circle...
# 453  igene biotechnology inc said terminated license agreement hercules inc hpc manufacture igenes na...
# 454  arizona silver corp said diamond drilling burro creek mine property located 65 miles southeast k...
# 455  british sugar plc forced shut ipswich sugar factory sunday afternoon due acute shortage beet sup...
# 456  phelps dodge corp said net earnings nearly tripled third quarter sharply higher copper prices in...
# 457  salomon brothers inc withdrawing market maker euroyen bonds contrary strong market rumours circu...
# 458  shr 47 cts vs 48 cts net 5050 mln vs 5330 mln revs 847 billion vs 843 billion nine mths shr 142 ...
# 459  american stock exchange said introduced options expirations three years institutional index tick...
#
#                                                                            predicted ranking  \
# 0     [(Topics, 1.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 1     [(Places, 1.0), (Topics, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 2     [(Topics, 1.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 3     [(Topics, 0.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 4     [(Topics, 0.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 5     [(Topics, 0.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 6     [(Topics, 0.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 7     [(Topics, 1.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 8     [(Topics, 0.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 9     [(Topics, 2.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 10    [(Topics, 1.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 11    [(Topics, 1.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 12    [(Peoples, 1.0), (Topics, 0.0), (Places, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 13    [(Topics, 0.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 14    [(Topics, 0.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 15    [(Topics, 1.0), (Organizations, 1.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0)]
# 16    [(Topics, 0.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 17    [(Topics, 0.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 18    [(Topics, 0.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 19    [(Topics, 0.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 20    [(Topics, 0.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 21    [(Topics, 0.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 22    [(Topics, 0.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 23    [(Topics, 0.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 24    [(Topics, 3.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 25    [(Topics, 0.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 26    [(Topics, 0.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 27    [(Organizations, 4.0), (Topics, 0.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0)]
# 28    [(Topics, 1.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 29    [(Topics, 0.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# ..                                                                                       ...
# 430  [(Places, 12.0), (Topics, 1.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 431   [(Topics, 0.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 432   [(Topics, 2.0), (Places, 2.0), (Exchanges, 1.0), (Peoples, 0.0), (Organizations, 0.0)]
# 433   [(Topics, 0.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 434   [(Topics, 8.0), (Places, 4.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 435  [(Places, 12.0), (Topics, 7.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 436  [(Topics, 11.0), (Places, 8.0), (Organizations, 7.0), (Peoples, 0.0), (Exchanges, 0.0)]
# 437   [(Topics, 0.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 438   [(Topics, 0.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 439   [(Topics, 0.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 440   [(Topics, 8.0), (Places, 4.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 441   [(Topics, 5.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 442   [(Exchanges, 1.0), (Topics, 0.0), (Places, 0.0), (Peoples, 0.0), (Organizations, 0.0)]
# 443   [(Places, 4.0), (Topics, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 444   [(Places, 8.0), (Topics, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 445   [(Places, 6.0), (Topics, 1.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 446   [(Topics, 0.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 447   [(Topics, 6.0), (Places, 6.0), (Peoples, 1.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 448   [(Places, 4.0), (Topics, 1.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 449  [(Topics, 20.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 450   [(Topics, 2.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 451  [(Topics, 11.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 452   [(Topics, 0.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 453  [(Topics, 20.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 454   [(Topics, 0.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 455   [(Peoples, 1.0), (Topics, 0.0), (Places, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 456   [(Topics, 2.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 457   [(Topics, 5.0), (Exchanges, 4.0), (Places, 0.0), (Peoples, 0.0), (Organizations, 0.0)]
# 458   [(Topics, 0.0), (Places, 0.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
# 459  [(Places, 12.0), (Topics, 2.0), (Peoples, 0.0), (Exchanges, 0.0), (Organizations, 0.0)]
#
#                                                                     actual ranking
# 0     [(Topics, 1), (Places, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 1     [(Places, 2), (Peoples, 1), (Organizations, 1), (Topics, 0), (Exchanges, 0)]
# 2     [(Places, 1), (Topics, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 3     [(Topics, 0), (Places, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 4     [(Topics, 0), (Places, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 5     [(Topics, 0), (Places, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 6     [(Topics, 1), (Places, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 7     [(Topics, 2), (Places, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 8     [(Topics, 1), (Places, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 9     [(Topics, 3), (Places, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 10    [(Topics, 0), (Places, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 11    [(Topics, 0), (Places, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 12    [(Topics, 1), (Places, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 13    [(Topics, 0), (Places, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 14    [(Topics, 0), (Places, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 15    [(Places, 1), (Topics, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 16    [(Topics, 0), (Places, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 17    [(Topics, 0), (Places, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 18    [(Topics, 0), (Places, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 19    [(Exchanges, 1), (Topics, 0), (Places, 0), (Peoples, 0), (Organizations, 0)]
# 20    [(Topics, 0), (Places, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 21    [(Topics, 0), (Places, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 22    [(Topics, 0), (Places, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 23    [(Topics, 0), (Places, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 24    [(Topics, 2), (Places, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 25    [(Topics, 0), (Places, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 26    [(Topics, 0), (Places, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 27    [(Topics, 0), (Places, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 28    [(Topics, 1), (Places, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 29    [(Places, 1), (Topics, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# ..                                                                             ...
# 430   [(Topics, 5), (Places, 2), (Organizations, 2), (Peoples, 1), (Exchanges, 0)]
# 431   [(Topics, 3), (Places, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 432   [(Topics, 2), (Places, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 433   [(Topics, 5), (Places, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 434   [(Peoples, 5), (Topics, 4), (Places, 1), (Exchanges, 0), (Organizations, 0)]
# 435   [(Topics, 3), (Peoples, 1), (Places, 0), (Exchanges, 0), (Organizations, 0)]
# 436   [(Topics, 0), (Places, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 437   [(Places, 2), (Topics, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 438   [(Topics, 2), (Places, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 439   [(Topics, 2), (Places, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 440   [(Topics, 9), (Peoples, 3), (Exchanges, 1), (Places, 0), (Organizations, 0)]
# 441   [(Topics, 3), (Places, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 442   [(Places, 2), (Topics, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 443   [(Topics, 1), (Places, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 444   [(Places, 2), (Topics, 1), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 445   [(Topics, 0), (Places, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 446   [(Peoples, 4), (Topics, 0), (Places, 0), (Exchanges, 0), (Organizations, 0)]
# 447   [(Topics, 5), (Places, 3), (Peoples, 2), (Exchanges, 0), (Organizations, 0)]
# 448   [(Topics, 1), (Places, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 449   [(Topics, 6), (Places, 1), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 450   [(Topics, 0), (Places, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 451   [(Peoples, 5), (Topics, 0), (Places, 0), (Exchanges, 0), (Organizations, 0)]
# 452   [(Places, 2), (Topics, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 453   [(Topics, 1), (Places, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 454   [(Topics, 4), (Places, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 455  [(Topics, 11), (Places, 2), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 456   [(Topics, 4), (Places, 0), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 457   [(Peoples, 4), (Topics, 2), (Organizations, 2), (Places, 0), (Exchanges, 0)]
# 458   [(Topics, 2), (Places, 1), (Peoples, 0), (Exchanges, 0), (Organizations, 0)]
# 459   [(Exchanges, 3), (Topics, 0), (Places, 0), (Peoples, 0), (Organizations, 0)]
#
# [460 rows x 3 columns]
